# %% [markdown]
# The purpose of this notebook is to find all of the possible decay chains based off of the data in livechart.

# %%
using Unitful #https://painterqubits.github.io/Unitful.jl/stable/
#quantity * @u_str("unit abbreviation") 
using Symbolics #https://symbolics.juliasymbolics.org/dev/
#cite https://doi.org/10.48550/arXiv.2105.03949
using Latexify
using Test
#1 * @u_str("mA") is 1 milliamp
using CSV, DataFrames
#using Plots
using PlotlyJS
using Printf
using SymPy #https://docs.juliahub.com/SymPy/ 
using PDFIO
using Unzip
using Interpolations
using Downloads
#plotlyjs()
data_dir = ("C:\\Cross-Section-Data\\")
cross_section_dir = data_dir
parent_dir = "C:\\Users\\engin\\Documents\\GitHub\\Energy\\"
endf8_decay_dir = cross_section_dir * "ENDF_Libraries-2\\ENDF-B-VIII.0\\decay\\"
jeff33_decay_dir = cross_section_dir * "ENDF_Libraries-2\\JEFF-3.3\\decay\\"
jendl5_decay_dir = cross_section_dir * "jendl5-dec_upd5\\"
# Out:
# "C:\\Cross-Section-Data\\jendl5-dec_upd5\\"

# %% [markdown]
# Now I will find the average decay energies for each nuclide. For the datasets I am using, the average decay energies are all given in keV.

# %%
function get_mass_name(nuclide)
    index = 1
    while (tryparse(Int64, string(nuclide[index])) != nothing && index <= length(nuclide))
        index += 1
    end
    mass = tryparse(Int64, nuclide[1:index-1])
    name =  nuclide[index:end]
    name_1 = uppercase(name[1])
    if (length(name) > 1)
        name = name_1 * name[2]
    else 
      name = name_1
    end
    return mass, name
end
element_symbols = ["H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne", 
"Na", "Mg", "Al", "Si", "P", "S", "Cl", "Ar", "K", "Ca", "Sc", "Ti", "V", 
"Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", 
"Kr", "Rb", "Sr", "Y", "Zr", "Nb", "Mo", "Tc", "Ru", "Rh", "Pd", "Ag", 
"Cd", "In", "Sn", "Sb", "Te", "I", "Xe", "Cs", "Ba", "La", "Ce", "Pr", 
"Nd", "Pm", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", 
"Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au", "Hg", "Tl", "Pb", "Bi", 
"Po", "At", "Rn", "Fr", "Ra", "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", 
"Cm", "Bk", "Cf", "Es", "Fm", "Md", "No", "Lr", "Rf", "Db", "Sg", "Bh", 
"Hs", "Mt", "Ds", "Rg", "Cn", "Nh", "Fl", "Mc", "Lv", "Ts", "Og"];

# %% [markdown]
# Rename files in directory to be easier to parse by removing zero-padding.

# %%
function unzero_pad(num_str) 
    if (num_str == '0')
        return num_str
    end
    i = 1
    while i < length(num_str) && num_str[i] == '0'
        i += 1
    end
    return num_str[i : end]
end
function rename_files_in_dir(dir, cutoff_index)
    for f in readdir(dir)
        if tryparse(Int64, string(f[1])) == nothing
            mv(dir * f, dir * f[cutoff_index:end])
        end
        if f != join(unzero_pad.(split(f, "-")), "-")
            mv(dir * f, dir * join(unzero_pad.(split(f, "-")), "-"))
        end
    end
end
rename_files_in_dir(endf8_decay_dir, 12)
rename_files_in_dir(jeff33_decay_dir, 12)
rename_files_in_dir(jendl5_decay_dir, 4)

# %%
function get_decay_energy_from_file(file_as_arr, search_string)
    line = [l for l in file_as_arr if length(l) > length(search_string)
             && occursin(search_string, l)]
    if (length(line) > 0)
        line = String(line[1])
        line = join(split(line, search_string, keepempty = false))
        return tryparse(Float64, join(split(line, " ", keepempty = false)[1]))
    else 
        return "Energy not found"
    end
end
# Out:
# get_decay_energy_from_file (generic function with 1 method)

# %% [markdown]
# This dictionary stores what strings to look to for in the datasets to find the average energy for each decay type, and for each directory.

# %%
dir_search_string_dict = Dict([
    jeff33_decay_dir => Dict(["alpha" => "ALPHA ENERGY                   =",
    "beta-minus" => "MEAN BETA- ENERGY              =","gamma" => "MEAN GAMMA ENERGY              =", 
    "x-ray" => "MEAN X-RAY ENERGY              =", "auger" => "MEAN AUGER ELECTRON ENERGY     ="
    ]),

    endf8_decay_dir => Dict(["alpha" => "Mean Alpha Energy:", 
    "beta-minus" => "Mean B- Energy:", "beta-plus" => "Mean B+ Energy:",
    "gamma" => "Mean Gamma Energy:", "auger" => "Mean CE+Auger Energy:",
    "neutron" => "Mean Neutron Energy:", "proton" => "Mean Neutron Energy:"]),

    jendl5_decay_dir => Dict(["alpha" => "Mean Alpha Energy",
    "beta-minus" => "Mean B- Energy", "gamma" => "Mean Gamma Energy",
    "neutron" => "Mean Neutron Energy", "proton" => "Mean Proton Energy",
    "auger" => "Mean CE+Auger Energy", 
    "beta-plus and electron capture" => "Mean B+/EC Energy"])  
])
# Out:
# Dict{String, Dict{String, String}} with 3 entries:
#   "C:\\Cross-Section-Data\… => Dict("auger"=>"Mean CE+Auger Energy", "beta-plus…
#   "C:\\Cross-Section-Data\… => Dict("auger"=>"Mean CE+Auger Energy:", "proton"=…
#   "C:\\Cross-Section-Data\… => Dict("auger"=>"MEAN AUGER ELECTRON ENERGY     ="…

# %%
function find_avg_decay_energy(nuclide, decay_type, dir)
    a, el = get_mass_name(nuclide)
    el = string(el)
    z = [i for i in 1:length(element_symbols) if element_symbols[i] == el][1]
    file_name = string(z) * "-" * el * "-" * string(a) * ".dat"
    file_path = dir * file_name
    file_as_array = split(open(f->read(f, String), file_path), "\n")
    search_string = dir_search_string_dict[dir][decay_type]
    return get_decay_energy_from_file(file_as_array, search_string)
end
dir_list = keys(dir_search_string_dict)
function find_avg_decay_energy(nuclide, decay_type)
    for dir in dir_list
        energy = find_avg_decay_energy(nuclide, decay_type, dir)
        if energy != "Energy not found"
            return energy
        end
    end
    return "Energy not found"
end
# Out:
# find_avg_decay_energy (generic function with 2 methods)

# %% [markdown]
# Now for some examples. Again, all average decay energies are given in keV.

# %%
out = find_avg_decay_energy("238U", "alpha", jeff33_decay_dir)
# Out:
# 4187.0737

# %%
out = find_avg_decay_energy("3H", "beta-minus", jendl5_decay_dir)
# Out:
# 5.69

# %%
avg_decay_energy = find_avg_decay_energy("8Be", "alpha", jendl5_decay_dir)
# Out:
# "Energy not found"

# %%
avg_decay_energy = find_avg_decay_energy("8Be", "alpha", jendl5_decay_dir)
if avg_decay_energy == "Energy not found"
    avg_decay_energy = find_avg_decay_energy("8Be", "alpha", jeff33_decay_dir)
end
# Out:
# 45.95

# %%
find_avg_decay_energy("238U", "alpha", endf8_decay_dir)
# Out:
# 4187.0

# %%
live_chart_file_name = "all_livechart_decays_and_emissions.csv"
all_live_chart_data = CSV.read(parent_dir * "ImportedData\\" * live_chart_file_name,
                        DataFrame, stringtype = String)[:,2:end]
# Out:
# 20202×54 DataFrame
#    Row │ z      n      symbol  radius   unc_r         abundance  abundance_unc ⋯
#        │ Int64  Int64  String  String   Float64?      String     String?       ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │     0      1  Nn      -0.1149        0.0027             missing       ⋯
#      2 │     0      4  N                missing                  missing
#      3 │     0      6  N                missing                  missing
#      4 │     1      0  H       0.8783         0.0086  99.9855    78
#      5 │     1      1  H       2.1421         0.0088  0.0145     78            ⋯
#      6 │     1      2  H       1.7591         0.0363             missing
#      7 │     1      3  H                missing                  missing
#      8 │     1      4  H                missing                  missing
#      9 │     1      5  H                missing                  missing       ⋯
#     10 │     1      6  H                missing                  missing
#     11 │     2      1  He      1.9661         0.003   0.0002     2
#    ⋮   │   ⋮      ⋮      ⋮        ⋮          ⋮            ⋮            ⋮       ⋱
#  20193 │   115    174  Mc               missing                  missing
#  20194 │   115    175  Mc               missing                  missing       ⋯
#  20195 │   116    174  Lv               missing                  missing
#  20196 │   116    175  Lv               missing                  missing
#  20197 │   116    176  Lv               missing                  missing
#  20198 │   116    177  Lv               missing                  missing       ⋯
#  20199 │   116    178  Lv               missing                  missing
#  20200 │   117    176  Ts               missing                  missing
#  20201 │   117    177  Ts               missing                  missing
#  20202 │   118    176  Og               missing                  missing       ⋯
#                                                47 columns and 20181 rows omitted

# %%
all_live_chart_data[!, "nuclide"] = [string(all_live_chart_data[row, "z"] + 
                        all_live_chart_data[row, "n"]) * all_live_chart_data[row, "symbol"]
                        for row in 1:size(all_live_chart_data)[1]]
livechart_nuclides = unique(all_live_chart_data[!, "nuclide"])
# Out:
# 3367-element Vector{String}:
#  "1Nn"
#  "4N"
#  "6N"
#  "1H"
#  "2H"
#  "3H"
#  "4H"
#  "5H"
#  "6H"
#  "7H"
#  "3He"
#  "4He"
#  "5He"
#  ⋮
#  "287Mc"
#  "288Mc"
#  "289Mc"
#  "290Mc"
#  "290Lv"
#  "291Lv"
#  "292Lv"
#  "293Lv"
#  "294Lv"
#  "293Ts"
#  "294Ts"
#  "294Og"

# %%
top_decay_probs = [tryparse(BigFloat, p) for p in all_live_chart_data[!,"decay_1_%"] 
                    if tryparse(Float64, p) != nothing]
decay_prob_df = DataFrame(Prob = top_decay_probs)
# Out:
# 17358×1 DataFrame
#    Row │ Prob
#        │ BigFloat
# ───────┼──────────
#      1 │    100.0
#      2 │    100.0
#      3 │    100.0
#      4 │    100.0
#      5 │    100.0
#      6 │    100.0
#      7 │    100.0
#      8 │    100.0
#      9 │    100.0
#     10 │    100.0
#     11 │    100.0
#    ⋮   │    ⋮
#  17349 │    100.0
#  17350 │    100.0
#  17351 │    100.0
#  17352 │    100.0
#  17353 │    100.0
#  17354 │    100.0
#  17355 │    100.0
#  17356 │    100.0
#  17357 │    100.0
#  17358 │    100.0
# 17337 rows omitted

# %%
plot(decay_prob_df, x=:Prob, kind = "histogram", nbinsx=100, 
Layout(yaxis_type = "log"))
# Out:
# data: [
#   "histogram with fields nbinsx, type, x, xaxis, and yaxis"
# ]
#
# layout: "layout with fields legend, margin, template, xaxis, and yaxis"

# %%
names(all_live_chart_data)[41:end]
# Out:
# 15-element Vector{String}:
#  "sn"
#  "unc_sn"
#  "sp"
#  "unc_sp"
#  "binding"
#  "unc_ba"
#  "atomic_mass"
#  "unc_am"
#  "massexcess"
#  "unc_me"
#  "ENSDFpublicationcut-off"
#  "ENSDFauthors"
#  "Extraction_date"
#  "Decay or Emission type"
#  "nuclide"

# %%
all_live_chart_data[!, "Decay or Emission type"]
# Out:
# 20202-element PooledArrays.PooledVector{String, UInt32, Vector{UInt32}}:
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  ⋮
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"

# %%
all_live_chart_data[!, "half_life_sec"]
# Out:
# 20202-element Vector{String}:
#  "613.9"
#  "1.7547604425822527e-22"
#  " "
#  " "
#  " "
#  "388781328.00697345"
#  " "
#  "8.608258774931805e-23"
#  "2.943469129492811e-22"
#  "5.069307945237619e-21"
#  " "
#  " "
#  "7.040705479496693e-22"
#  ⋮
#  " "
#  "0.17"
#  "0.22"
#  "0.65"
#  "0.0083"
#  " "
#  "0.0128"
#  "0.053"
#  " "
#  "0.014"
#  "0.051"
#  "0.00058"

# %% [markdown]
# Note that based on the documentation for the livechart API, the decay type denoted "B+" also includes electron capture.
#
# Source:
#
# https://www-nds.iaea.org/relnsd/vcharthtml/api_v0_guide.html#apirad_type

# %%
decay_or_emission_type_dict = Dict([
    "B-" =>  "beta minus decay", "A" =>  "alpha decay", "B+" =>  "beta plus decay",
    "EC" => "auger and conversion electron"
])
function get_half_life(nuclide, decay_type)
    if decay_type == "EC+B+" 
        decay_type = "B+"
    end
    if decay_type in keys(decay_or_emission_type_dict)
        decay_type_long = decay_or_emission_type_dict[decay_type]
        row = [row for row in 1:size(all_live_chart_data)[1]
                if ((all_live_chart_data[row, "nuclide"] ==  nuclide) && 
                (decay_type_long == all_live_chart_data[row, "Decay or Emission type"])
                )][1]
        return all_live_chart_data[row, "half_life_sec"]
    end
    if decay_type in values(decay_or_emission_type_dict)
        row = [row for row in 1:size(all_live_chart_data)[1]
                if (all_live_chart_data[row, "nuclide"] ==  nuclide && 
                decay_type == all_live_chart_data[row, "Decay or Emission type"])][1]
        return all_live_chart_data[row, "half_life_sec"]
    end
    return decay_type * " not accounted for "
end
# Out:
# get_half_life (generic function with 1 method)

# %%
all_live_chart_data[!, "nuclide"]
# Out:
# 20202-element Vector{String}:
#  "1Nn"
#  "4N"
#  "6N"
#  "1H"
#  "2H"
#  "3H"
#  "4H"
#  "5H"
#  "6H"
#  "7H"
#  "3He"
#  "4He"
#  "5He"
#  ⋮
#  "287Mc"
#  "288Mc"
#  "289Mc"
#  "290Mc"
#  "290Lv"
#  "291Lv"
#  "292Lv"
#  "293Lv"
#  "294Lv"
#  "293Ts"
#  "294Ts"
#  "294Og"

# %%
all_live_chart_data[!, "Decay or Emission type"]
# Out:
# 20202-element PooledArrays.PooledVector{String, UInt32, Vector{UInt32}}:
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  "beta minus decay"
#  ⋮
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"
#  "x ray emission"

# %%
decay_type = "B-"
nuclide = "3H"
decay_type_long = decay_or_emission_type_dict[decay_type]
# Out:
# "beta minus decay"

# %%
all_live_chart_data[6, "Decay or Emission type"]
# Out:
# "beta minus decay"

# %%
function get_daughter_nuclide(parent, decay_type)
    if decay_type == "gamma"
        return parent
    end
    mass, el = get_mass_name(parent)
    el_index = [i for i in 1:length(element_symbols)
                if element_symbols[i] == string(el)][1]
    if decay_type == "alpha" || decay_type == "A"
        return string(mass - 4) * element_symbols[el_index - 2]
    end
    if decay_type == "beta-minus" || decay_type == "B-"
        return string(mass) * element_symbols[el_index + 1]
    end
    if decay_type == "beta-plus" || decay_type == "B+" ||  decay_type == "EC+B+"
        return string(mass) * element_symbols[el_index - 1]
    end
    if decay_type == "neutron" || decay_type == "N"
        return string(mass-1) * el
    end
    if decay_type == "proton" || decay_type == "P"
        return string(mass-1) * element_symbols[el_index - 1]
    end
    if decay_type == "double neutron" || decay_type == "2N"
        return string(mass-2) * el
    end
    if decay_type == "double proton" || decay_type == "2P"
        return string(mass-2) * element_symbols[el_index - 2]
    end
    if decay_type == "double neutron" || decay_type == "2N"
        return string(mass-2) * element_symbols[el_index - 1]
    end
    return decay_type * " not yet accounted for"
end
# Out:
# get_daughter_nuclide (generic function with 1 method)

# %%
livechart_abbreviation_decay_types = Dict([
    "A" => "alpha", "B-" => "beta-minus", "B+" => "beta-plus", 
    "N" => "neutron", "P" => "proton", "EC+B+" => "beta-plus and electron capture",
    "EC" => "electron capture"
])
unique(all_live_chart_data[!,"decay_1"])
# Out:
# 21-element Vector{String}:
#  "B-"
#  " "
#  "N"
#  "2N"
#  "P"
#  "A"
#  "EC"
#  "EC+B+"
#  "2P"
#  "B+P"
#  "B-N"
#  "B-2N"
#  "B+"
#  "2B-"
#  "ECP+EC2P"
#  "2EC"
#  "IT"
#  "ECP"
#  "2B+"
#  "SF"
#  "ECSF"

# %% [markdown]
# The function named decay returns all vector describing all of the possible decay paths for a given parent nuclide. Each decay path in the vector includes the decay type, the probability of that decay type occurring as a percentage, and what daughter isotope will be produced.

# %%
function decay(parent)
    if occursin("not yet accounted for", parent)
        return parent
    end
    row = 1
    #mass, elem = 
    while (row < size(all_live_chart_data)[1]
        && all_live_chart_data[row, "nuclide"] != parent)
        row += 1
    end 
    decay_types = (all_live_chart_data[row, "decay_1"], all_live_chart_data[row, "decay_2"],
                    all_live_chart_data[row, "decay_3"])
    if decay_types[1] == " "
        return "stable"
    end
    decay_percents =  (all_live_chart_data[row, "decay_1_%"], all_live_chart_data[row, "decay_2_%"],
                        all_live_chart_data[row, "decay_3_%"])
    direct_daughters = [get_daughter_nuclide(parent, decay_type) 
                        for decay_type in decay_types if decay_type != " "]
    decay_energies = Vector{Any}(undef, length(direct_daughters))
    half_lives = Vector{Any}(undef, length(direct_daughters))
    for i in 1:length(direct_daughters)
        decay_type = decay_types[i] 
        half_lives[i] = get_half_life(parent, decay_type)
        if !occursin("not accounted for ", half_lives[i])
            half_lives[i] = half_lives[i] * "seconds"
        end
        if decay_type in keys(livechart_abbreviation_decay_types)
            decay_energies[i] = string(find_avg_decay_energy(parent, 
                        livechart_abbreviation_decay_types[decay_type])) * "keV"
        else 
            decay_energies[i] = decay_type * " not yet accounted for"
        end
    end
    return [(decay_types[i], decay_percents[i] * "%", decay_energies[i],
            half_lives[i], direct_daughters[i])
            for i in 1:length(direct_daughters)]
end
chain = decay("238U")
# Out:
# 2-element Vector{NTuple{5, String}}:
#  ("A", "100%", "4187.13keV", "1.4099634525447706e17seconds", "234Th")
#  ("SF", "0.0000545%", "SF not yet accounted for", "SF not accounted for ", "SF not yet accounted for")

# %% [markdown]
# Each decay route will be stored as its own string of the form isotope,decay type,probability,average energy released, daughter isotope.
#
# For example,
#
# "3H,B-,100%,5.69keV,3He"
#
#  means that 100% of tritium decays are beta-minus decay, and on average the produced beta particles will have a kinetic energy of 5.69 keV.

# %%
function add_to_decay_route_string(parent)
    if occursin(",", parent) 
        if decay_route_complete(parent)
            return parent
        end
        decay_route = parent
        parent = split(parent, ",")[end]
        decay_result = decay(parent)
        if typeof(decay_result) == String
            return [decay_route * "," * decay_result]
        end
        return [decay_route * "," * join(d, ",") for d in decay(parent)]
    end
    decay_result = decay(parent)
    if typeof(decay_result) == String
        return [parent * "," * decay_result]
    end
    return [parent * "," * join(d, ",") for d in decay(parent)]
end
# Out:
# add_to_decay_route_string (generic function with 1 method)

# %%
decay_route_complete(decay_route) = (occursin("not yet accounted for", decay_route)
                                    ||occursin("stable", decay_route))
all_decay_routes_complete(decay_routes) = (sum([
    decay_route_complete(decay_route) for decay_route in decay_routes]) 
    == length(decay_routes))
# Out:
# all_decay_routes_complete (generic function with 1 method)

# %%
decay_route_strs = [add_to_decay_route_string("238U")]
!all_decay_routes_complete(add_to_decay_route_string("238U"))
# Out:
# true

# %%
function make_complete_decay_chain(nuclide)
    decay_route_strs = add_to_decay_route_string(nuclide)
    while !all_decay_routes_complete(decay_route_strs)
        decay_routes_copy = decay_route_strs 
        for i in 1:length(decay_routes_copy)
            if !decay_route_complete(decay_route_strs[i])
                new_decay_routes = add_to_decay_route_string(decay_route_strs[i])
                decay_route_strs[i] = string(new_decay_routes[1])
                if length(new_decay_routes) > 1
                    decay_route_strs = vcat(decay_route_strs, new_decay_routes[2:end])
                end
            end
        end
    end
    return decay_route_strs
end
# Out:
# make_complete_decay_chain (generic function with 1 method)

# %%
make_complete_decay_chain("238U")
# Out:
# 25-element Vector{String}:
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 551 bytes ⋯ "11955686.4seconds,206Pb,stable"
#  "238U,SF,0.0000545%,SF not yet a" ⋯ 28 bytes ⋯ "d for ,SF not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 160 bytes ⋯ " for ,SF not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 161 bytes ⋯ " for ,Mg not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 218 bytes ⋯ "or ,24NE not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 210 bytes ⋯ " for ,SF not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 261 bytes ⋯ "for ,14C not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 549 bytes ⋯ "11955686.4seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 546 bytes ⋯ "11955686.4seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 540 bytes ⋯ "11955686.4seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 419 bytes ⋯ "for ,B-A not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 538 bytes ⋯ "11955686.4seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 417 bytes ⋯ "for ,B-A not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 456 bytes ⋯ "for ,B-N not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 454 bytes ⋯ "for ,B-N not yet accounted for"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 549 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 547 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 544 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 538 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 536 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 553 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 551 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 548 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 542 bytes ⋯ "keV,252.12seconds,206Pb,stable"
#  "238U,A,100%,4187.13keV,1.409963" ⋯ 540 bytes ⋯ "keV,252.12seconds,206Pb,stable"

# %% [markdown]
# For small nuclides, it only takes about 1 second for 100 nuclides. For large nuclides, it takes 1 minute for 100 nuclides.

# %% [markdown]
# Export the comprehensive decay chains of each nuclide into a directory and store them in the Julia workspace as a dictionary.

# %%
comprehensive_decay_chains_dir = cross_section_dir * "Comprehensive_decay_chains\\"
decay_dict = Dict([])
for nuclide in livechart_nuclides
    try
        decay_dict[nuclide] = make_complete_decay_chain(nuclide)
        CSV.write(comprehensive_decay_chains_dir * nuclide * ".csv", 
                    DataFrame(decay_routes = decay_dict[nuclide]))
    catch
        println(nuclide, " did not work")
    end
end
decay_dict
# Out:
# 1Nn did not work
# 5He did not work
# 9He did not work
# 10He did not work
# 4Li did not work
# 5Li did not work
# 10Li did not work
# 12Li did not work
# 6Be did not work
# 7Be did not work
# 13Be did not work
# 15Be did not work
# 16Be did not work
# 7B did not work
# 9B did not work
# 16B did not work
# 18B did not work
# 20B did not work
# 10N did not work
# 11N did not work
# 24N did not work
# 15F did not work
# 28F did not work
# 30F did not work
# 33Ne did not work
# 18Na did not work
# 19Na did not work
# 20Na did not work
# 36Na did not work
# 20Mg did not work
# 39Mg did not work
# 21Al did not work
# 43Al did not work
# 25P did not work
# 26S did not work
# 29Cl did not work
# 30Cl did not work
# 52Cl did not work
# 31Ar did not work
# 37Ar did not work
# 33K did not work
# 34K did not work
# 56K did not work
# 34Ca did not work
# 41Ca did not work
# 58Ca did not work
# 38Sc did not work
# 39Sc did not work
# 61Sc did not work
# 44Ti did not work
# 64Ti did not work
# 42V did not work
# 43V did not work
# 49V did not work
# 67V did not work
# 45Cr did not work
# 51Cr did not work
# 44Mn did not work
# 53Mn did not work
# 55Fe did not work
# 48Co did not work
# 51Co did not work
# 57Co did not work
# 49Ni did not work
# 53Cu did not work
# 54Cu did not work
# 55Cu did not work
# 56Cu did not work
# 55Zn did not work
# 56Zn did not work
# 59Ga did not work
# 67Ga did not work
# 70Ga did not work
# 59Ge did not work
# 60Ge did not work
# 62Ge did not work
# 63Ge did not work
# 68Ge did not work
# 71Ge did not work
# 63As did not work
# 64As did not work
# 65As did not work
# 73As did not work
# 64Se did not work
# 65Se did not work
# 66Se did not work
# 72Se did not work
# 75Se did not work
# 69Br did not work
# 101Br did not work
# 81Kr did not work
# 72Rb did not work
# 73Rb did not work
# 83Rb did not work
# 86Rb did not work
# 106Rb did not work
# 74Sr did not work
# 82Sr did not work
# 85Sr did not work
# 108Sr did not work
# 76Y did not work
# 110Y did not work
# 111Y did not work
# 77Zr did not work
# 78Zr did not work
# 79Zr did not work
# 88Zr did not work
# 113Zr did not work
# 114Zr did not work
# 81Nb did not work
# 116Nb did not work
# 117Nb did not work
# 81Mo did not work
# 82Mo did not work
# 83Mo did not work
# 93Mo did not work
# 119Mo did not work
# 85Tc did not work
# 87Tc did not work
# 90Tc did not work
# 97Tc did not work
# 100Tc did not work
# 122Tc did not work
# 85Ru did not work
# 86Ru did not work
# 88Ru did not work
# 89Ru did not work
# 94Ru did not work
# 125Ru did not work
# 89Rh did not work
# 90Rh did not work
# 101Rh did not work
# 90Pd did not work
# 91Pd did not work
# 92Pd did not work
# 95Pd did not work
# 100Pd did not work
# 103Pd did not work
# 92Ag did not work
# 93Ag did not work
# 94Ag did not work
# 97Ag did not work
# 110Ag did not work
# 94Cd did not work
# 95Cd did not work
# 96Cd did not work
# 97Cd did not work
# 109Cd did not work
# 96In did not work
# 97In did not work
# 98In did not work
# 111In did not work
# 116In did not work
# 99Sn did not work
# 110Sn did not work
# 103Sb did not work
# 104Sb did not work
# 105Sb did not work
# 117Sb did not work
# 119Sb did not work
# 141Sb did not work
# 104Te did not work
# 117Te did not work
# 118Te did not work
# 119Te did not work
# 123Te did not work
# 108I did not work
# 109I did not work
# 117I did not work
# 119I did not work
# 125I did not work
# 108Xe did not work
# 122Xe did not work
# 127Xe did not work
# 112Cs did not work
# 113Cs did not work
# 115Cs did not work
# 120Cs did not work
# 131Cs did not work
# 134Cs did not work
# 115Ba did not work
# 118Ba did not work
# 119Ba did not work
# 128Ba did not work
# 133Ba did not work
# 117La did not work
# 120La did not work
# 128La did not work
# 137La did not work
# 122Ce did not work
# 131Ce did not work
# 134Ce did not work
# 139Ce did not work
# 121Pr did not work
# 142Pr did not work
# 126Nd did not work
# 127Nd did not work
# 140Nd did not work
# 128Pm did not work
# 143Pm did not work
# 145Pm did not work
# 146Pm did not work
# 129Sm did not work
# 130Sm did not work
# 132Sm did not work
# 145Sm did not work
# 130Eu did not work
# 131Eu did not work
# 132Eu did not work
# 134Eu did not work
# 137Eu did not work
# 147Eu did not work
# 149Eu did not work
# 137Gd did not work
# 149Gd did not work
# 151Gd did not work
# 153Gd did not work
# 138Tb did not work
# 151Tb did not work
# 155Tb did not work
# 157Tb did not work
# 173Tb did not work
# 174Tb did not work
# 140Dy did not work
# 153Dy did not work
# 159Dy did not work
# 174Dy did not work
# 175Dy did not work
# 176Dy did not work
# 141Ho did not work
# 143Ho did not work
# 144Ho did not work
# 161Ho did not work
# 163Ho did not work
# 176Ho did not work
# 177Ho did not work
# 178Ho did not work
# 144Er did not work
# 146Er did not work
# 158Er did not work
# 160Er did not work
# 165Er did not work
# 178Er did not work
# 179Er did not work
# 180Er did not work
# 144Tm did not work
# 145Tm did not work
# 147Tm did not work
# 164Tm did not work
# 167Tm did not work
# 170Tm did not work
# 180Tm did not work
# 181Tm did not work
# 164Yb did not work
# 166Yb did not work
# 169Yb did not work
# 182Yb did not work
# 183Yb did not work
# 184Yb did not work
# 185Yb did not work
# 173Lu did not work
# 185Lu did not work
# 186Lu did not work
# 187Lu did not work
# 188Lu did not work
# 155Hf did not work
# 170Hf did not work
# 172Hf did not work
# 175Hf did not work
# 189Hf did not work
# 190Hf did not work
# 156Ta did not work
# 161Ta did not work
# 179Ta did not work
# 180Ta did not work
# 191Ta did not work
# 193Ta did not work
# 194Ta did not work
# 157W did not work
# 159W did not work
# 176W did not work
# 178W did not work
# 181W did not work
# 193W did not work
# 194W did not work
# 195W did not work
# 196W did not work
# 197W did not work
# 160Re did not work
# 165Re did not work
# 183Re did not work
# 186Re did not work
# 195Re did not work
# 196Re did not work
# 197Re did not work
# 198Re did not work
# 199Re did not work
# 161Os did not work
# 163Os did not work
# 174Os did not work
# 182Os did not work
# 185Os did not work
# 197Os did not work
# 198Os did not work
# 199Os did not work
# 200Os did not work
# 201Os did not work
# 202Os did not work
# 203Os did not work
# 164Ir did not work
# 165Ir did not work
# 169Ir did not work
# 171Ir did not work
# 174Ir did not work
# 189Ir did not work
# 190Ir did not work
# 192Ir did not work
# 200Ir did not work
# 201Ir did not work
# 203Ir did not work
# 204Ir did not work
# 205Ir did not work
# 165Pt did not work
# 167Pt did not work
# 178Pt did not work
# 186Pt did not work
# 191Pt did not work
# 193Pt did not work
# 203Pt did not work
# 205Pt did not work
# 206Pt did not work
# 207Pt did not work
# 208Pt did not work
# 173Au did not work
# 175Au did not work
# 178Au did not work
# 195Au did not work
# 207Au did not work
# 208Au did not work
# 209Au did not work
# 210Au did not work
# 170Hg did not work
# 171Hg did not work
# 182Hg did not work
# 190Hg did not work
# 192Hg did not work
# 194Hg did not work
# 197Hg did not work
# 212Hg did not work
# 213Hg did not work
# 214Hg did not work
# 215Hg did not work
# 216Hg did not work
# 177Tl did not work
# 178Tl did not work
# 179Tl did not work
# 182Tl did not work
# 185Tl did not work
# 201Tl did not work
# 217Tl did not work
# 186Pb did not work
# 193Pb did not work
# 194Pb did not work
# 196Pb did not work
# 200Pb did not work
# 202Pb did not work
# 203Pb did not work
# 205Pb did not work
# 217Pb did not work
# 218Pb did not work
# 219Pb did not work
# 220Pb did not work
# 186Bi did not work
# 189Bi did not work
# 221Bi did not work
# 222Bi did not work
# 223Bi did not work
# 224Bi did not work
# 186Po did not work
# 190Po did not work
# 197Po did not work
# 198Po did not work
# 200Po did not work
# 204Po did not work
# 206Po did not work
# 207Po did not work
# 209Po did not work
# 221Po did not work
# 223Po did not work
# 224Po did not work
# 225Po did not work
# 226Po did not work
# 227Po did not work
# 193At did not work
# 211At did not work
# 216At did not work
# 224At did not work
# 225At did not work
# 226At did not work
# 227At did not work
# 228At did not work
# 229At did not work
# 194Rn did not work
# 201Rn did not work
# 202Rn did not work
# 204Rn did not work
# 208Rn did not work
# 210Rn did not work
# 211Rn did not work
# 213Rn did not work
# 229Rn did not work
# 197Fr did not work
# 198Fr did not work
# 206Fr did not work
# 211Fr did not work
# 215Fr did not work
# 216Fr did not work
# 220Fr did not work
# 201Ra did not work
# 205Ra did not work
# 206Ra did not work
# 208Ra did not work
# 212Ra did not work
# 214Ra did not work
# 215Ra did not work
# 216Ra did not work
# 217Ra did not work
# 205Ac did not work
# 208Ac did not work
# 210Ac did not work
# 214Ac did not work
# 215Ac did not work
# 219Ac did not work
# 220Ac did not work
# 223Ac did not work
# 224Ac did not work
# 226Ac did not work
# 208Th did not work
# 209Th did not work
# 210Th did not work
# 212Th did not work
# 216Th did not work
# 218Th did not work
# 219Th did not work
# 220Th did not work
# 221Th did not work
# 225Th did not work
# 211Pa did not work
# 212Pa did not work
# 214Pa did not work
# 216Pa did not work
# 218Pa did not work
# 219Pa did not work
# 220Pa did not work
# 223Pa did not work
# 224Pa did not work
# 227Pa did not work
# 228Pa did not work
# 229Pa did not work
# 230Pa did not work
# 232Pa did not work
# 214U did not work
# 215U did not work
# 216U did not work
# 221U did not work
# 222U did not work
# 223U did not work
# 224U did not work
# 225U did not work
# 228U did not work
# 229U did not work
# 231U did not work
# 243U did not work
# 244U did not work
# 245U did not work
# 246U did not work
# 247U did not work
# 248U did not work
# 249U did not work
# 250U did not work
# 251U did not work
# 252U did not work
# 253U did not work
# 254U did not work
# 255U did not work
# 219Np did not work
# 220Np did not work
# 223Np did not work
# 224Np did not work
# 225Np did not work
# 227Np did not work
# 228Np did not work
# 229Np did not work
# 231Np did not work
# 232Np did not work
# 233Np did not work
# 235Np did not work
# 236Np did not work
# 252Np did not work
# 228Pu did not work
# 229Pu did not work
# 232Pu did not work
# 233Pu did not work
# 234Pu did not work
# 235Pu did not work
# 237Pu did not work
# 252Pu did not work
# 223Am did not work
# 229Am did not work
# 230Am did not work
# 232Am did not work
# 233Am did not work
# 234Am did not work
# 235Am did not work
# 236Am did not work
# 237Am did not work
# 239Am did not work
# 240Am did not work
# 242Am did not work
# 252Am did not work
# 233Cm did not work
# 234Cm did not work
# 236Cm did not work
# 237Cm did not work
# 238Cm did not work
# 239Cm did not work
# 240Cm did not work
# 241Cm did not work
# 243Cm did not work
# 252Cm did not work
# 233Bk did not work
# 234Bk did not work
# 236Bk did not work
# 239Bk did not work
# 241Bk did not work
# 243Bk did not work
# 244Bk did not work
# 245Bk did not work
# 252Bk did not work
# 237Cf did not work
# 238Cf did not work
# 239Cf did not work
# 240Cf did not work
# 241Cf did not work
# 242Cf did not work
# 243Cf did not work
# 244Cf did not work
# 245Cf did not work
# 246Cf did not work
# 247Cf did not work
# 256Cf did not work
# 240Es did not work
# 241Es did not work
# 243Es did not work
# 244Es did not work
# 245Es did not work
# 248Es did not work
# 249Es did not work
# 250Es did not work
# 251Es did not work
# 252Es did not work
# 241Fm did not work
# 243Fm did not work
# 244Fm did not work
# 245Fm did not work
# 246Fm did not work
# 247Fm did not work
# 248Fm did not work
# 249Fm did not work
# 250Fm did not work
# 251Fm did not work
# 253Fm did not work
# 244Md did not work
# 245Md did not work
# 246Md did not work
# 247Md did not work
# 248Md did not work
# 249Md did not work
# 250Md did not work
# 252Md did not work
# 253Md did not work
# 255Md did not work
# 256Md did not work
# 257Md did not work
# 260Md did not work
# 249No did not work
# 250No did not work
# 251No did not work
# 252No did not work
# 253No did not work
# 254No did not work
# 255No did not work
# 257No did not work
# 252Lr did not work
# 253Lr did not work
# 254Lr did not work
# 255Lr did not work
# 256Lr did not work
# 257Lr did not work
# 258Lr did not work
# 259Lr did not work
# 260Lr did not work
# 262Lr did not work
# 253Rf did not work
# 254Rf did not work
# 255Rf did not work
# 256Rf did not work
# 257Rf did not work
# 258Rf did not work
# 259Rf did not work
# 261Rf did not work
# 255Db did not work
# 256Db did not work
# 257Db did not work
# 258Db did not work
# 259Db did not work
# 260Db did not work
# 261Db did not work
# 262Db did not work
# 263Db did not work
# 266Db did not work
# 268Db did not work
# 258Sg did not work
# 259Sg did not work
# 260Sg did not work
# 261Sg did not work
# 262Sg did not work
# 263Sg did not work
# 265Sg did not work
# 260Bh did not work
# 261Bh did not work
# 262Bh did not work
# 264Bh did not work
# 266Bh did not work
# 267Bh did not work
# 270Bh did not work
# 271Bh did not work
# 272Bh did not work
# 278Bh did not work
# 263Hs did not work
# 264Hs did not work
# 265Hs did not work
# 266Hs did not work
# 267Hs did not work
# 269Hs did not work
# 278Hs did not work
# 266Mt did not work
# 268Mt did not work
# 270Mt did not work
# 274Mt did not work
# 275Mt did not work
# 276Mt did not work
# 277Mt did not work
# 282Mt did not work
# 267Ds did not work
# 269Ds did not work
# 270Ds did not work
# 271Ds did not work
# 273Ds did not work
# 282Ds did not work
# 272Rg did not work
# 274Rg did not work
# 278Rg did not work
# 279Rg did not work
# 280Rg did not work
# 281Rg did not work
# 286Rg did not work
# 277Cn did not work
# 282Cn did not work
# 284Cn did not work
# 286Cn did not work
# 278Nh did not work
# 282Nh did not work
# 283Nh did not work
# 284Nh did not work
# 285Nh did not work
# 290Nh did not work
# 284Fl did not work
# 286Fl did not work
# 288Fl did not work
# 290Fl did not work
# 287Mc did not work
# 288Mc did not work
# 289Mc did not work
# 290Lv did not work
# 292Lv did not work
# 293Ts did not work
# 294Og did not work
# Dict{Any, Any} with 2679 entries:
#   "145Te" => ["145Te,B-,100%,2827.62keV, seconds,145I,B-, %,2468.0keV,0.0000004…
#   "43Si"  => ["43Si,B-N, %,B-N not yet accounted for,B-N not accounted for ,B-N…
#   "113Sn" => ["113Sn,EC+B+,100%,0.0keV,9943776seconds,EC+B+ not yet accounted f…
#   "106Nb" => ["106Nb,B-,100%,3313.0keV,1.02seconds,106Mo,B-,100%,1212.18keV,8.7…
#   "230Pu" => ["230Pu,A,100%,7045.98keV,102seconds,226U,A,100%,7539.15keV,0.268s…
#   "168Eu" => ["168Eu,B-,100%,2168.0keV,0.2seconds,168Gd,B-,100%,1521.0keV,3.03s…
#   "160Dy" => ["160Dy,stable"]
#   "18Ne"  => ["18Ne,EC+B+,100%,1499.16keV,1.672seconds,EC+B+ not yet accounted …
#   "75Cu"  => ["75Cu,B-,100%,2688.0keV,1.224seconds,75Zn,B-,100%,1893.42keV,10.2…
#   "162Sm" => ["162Sm,B-,100%,1383.0keV,2.4seconds,162Eu,B-,100%,655.68keV,10.6s…
#   "57V"   => ["57V,B-,100%,3558.89keV,0.32seconds,57Cr,B-,100%,1948.93keV,21.1s…
#   "208Po" => ["208Po,A,99.996%,5114.7keV,91451971.47436762seconds,204Pb,A, %,19…
#   "167Re" => ["167Re,EC+B+,99%,0.0keV,5.9seconds,EC+B+ not yet accounted for", …
#   "222Pa" => ["222Pa,A,100%,4227.89keV,0.0029seconds,218Ac,A,100%,nothingkeV,0.…
#   "21F"   => ["21F,B-,100%,2354.19keV,4.158seconds,21Ne,stable"]
#   "120Sn" => ["120Sn,stable"]
#   "144Gd" => ["144Gd,EC+B+,100%,0.0keV,268.2seconds,EC+B+ not yet accounted for…
#   "56Ni"  => ["56Ni,EC+B+,100%,0.000652keV,524880seconds,EC+B+ not yet accounte…
#   "162Dy" => ["162Dy,stable"]
#   "80Sr"  => ["80Sr,EC+B+,100%,35.78keV,6378seconds,EC+B+ not yet accounted for…
#   "118In" => ["118In,B-,100%,1879.0keV,5seconds,118Sn,stable"]
#   "188Bi" => ["188Bi,A,100%,6848.86keV,0.06seconds,184Tl,EC+B+,97.9%,0.0keV,10.…
#   "175Pt" => ["175Pt,A,64%,3792.53keV,2.53seconds,171Os,EC+B+,98.2%,1940.1keV,8…
#   "39Ti"  => ["39Ti,ECP+EC2P,100%,ECP+EC2P not yet accounted for,ECP+EC2P not a…
#   "59Zn"  => ["59Zn,EC+B+,100%,3827.5keV,0.1786seconds,EC+B+ not yet accounted …
#   ⋮       => ⋮

# %%
decay_dict["207Bi"]
# Out:
# 1-element Vector{String}:
#  "207Bi,EC+B+,100%,0.146keV,995621014.4983776seconds,EC+B+ not yet accounted for"
