# %% [markdown]
# Consider a spherical spaceship with many perfectly efficient particle accelerators pointed outwards. An astronaut turns one of them on. How much thrust does this generate?
#
# Each ejected particle is moving at relativistic speeds. In the reference frame of the ship, each particle has momentum $p$ and energy $E$, and are ejected at a rate I in counts/second (at some point this turns into $i$, which here is not $\sqrt{-1}$).

# %%
#only run this cell on google colab !pip install sympy -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (1.7.1)
# Collecting sympy
#   Downloading sympy-1.10.1-py3-none-any.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 6.5 MB/s
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy) (1.2.1)
# Installing collected packages: sympy
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.7.1
#     Uninstalling sympy-1.7.1:
#       Successfully uninstalled sympy-1.7.1
# Successfully installed sympy-1.10.1

# %%
from sympy.abc import *
from sympy import Q, Symbol
from sympy.parsing.sympy_parser import parse_expr
import numpy as np
import plotly.express as px
import sympy
import pandas as pd
import mpmath
#each particle has rest mass m_0
m_0 = sympy.symbols("m_0")
E = (y-1)*m_0*c**2
P = E*I
P
# Out:
# I*c**2*m_0*(y - 1)

# %%
sympy.assumptions.global_assumptions
# Out:
# set()

# %%
p = y*m_0*v
F = I * p
F
# Out:
# I*m_0*v*y

# %%
e = sympy.simplify(F/P)
e
# Out:
# v*y/(c**2*(y - 1))

# %% [markdown]
# which is equal to
# \begin{equation}
# \begin{split}
# \frac{\beta}{c}(1+\frac{1}{\gamma-1})\\
# \end{split}
# \end{equation}
# which is implemented in the function below

# %% [markdown]
# Using list comprehension with a condition so that sympy's slower but more precise calculations are only used when necessary.

# %%
def efficiency_from_v(v, dps = 50):
  mpmath.mp.dps = dps
  c = 299792458
  v = mpmath.mpmathify(v)
  b = v/c
  y = 1 / mpmath.sqrt(1 - b**2)
  try: 
    return (b/c)*(1+1/(y-1))
  except:
    if dps < 100:
      return efficiency_from_v(v, dps = 100)
    else:
      print("Failed with dps = ", dps)

# %%
c_num = 299792458
velocities = np.logspace(0, np.log10(.999 * c_num), 10**5)
efficiencies = np.array([np.float64(efficiency_from_v(velocity) )
                for velocity in velocities])

# %%
np.min(efficiencies), np.max(efficiencies)
# Out:
# (3.4882663183806444e-09, 2.0)

# %%
df = pd.DataFrame()
x_label = "Eject Particle Velocity (m/s)"
y_label = "Ratio of Thrust (N) to Power Consumed (W)"
df[x_label] = velocities
df[y_label] = efficiencies
px.scatter(df, x = x_label, y=y_label, log_y=True, log_x=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0576be7a-1958-40f8-b3a9-91683ab85b45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0576be7a-1958-40f8-b3a9-91683ab85b45")) {                    Plotly.newPlot(                        "0576be7a-1958-40f8-b3a9-91683ab85b45",                        [{"hovertemplate":"Eject Particle Velocity (m/s)=%{x}<br>Ratio of Thrust (N) to Power Consumed (W)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[1.0,1.0001951970050984,1.0003904321120674,1.0005857053283447,1.000781016661369,1.0009763661185807,1.0011717537074212,1.0013671794353338,1.0015626433097633,1.0017581453381559,1.0019536855279587,1.002149263886621,1.002344880421593,1.002540535140327,1.002736228050276,1.002931959158895,1.0031277284736402,1.0033235360019694,1.0035193817513417,1.0037152657292177,1.0039111879430596,1.0041071484003306,1.0043031471084962,1.0044991840750226,1.0046952593073777,1.004891372813031,1.0050875245994533,1.0052837146741167,1.0054799430444952,1.005676209718064,1.0058725147022995,1.0060688580046802,1.0062652396326854,1.0064616595937963,1.0066581178954952,1.0068546145452664,1.007051149550595,1.007247722918968,1.007444334657874,1.0076409847748025,1.007837673277245,1.0080344001726937,1.0082311654686436,1.00842796917259,1.0086248112920297,1.008821691834462,1.0090186108073862,1.0092155682183042,1.009412564074719,1.009609598384135,1.009806671154058,1.0100037823919956,1.0102009321054566,1.0103981203019512,1.010595346988991,1.0107926121740896,1.0109899158647615,1.0111872580685228,1.0113846387928913,1.0115820580453863,1.0117795158335279,1.0119770121648384,1.0121745470468413,1.0123721204870617,1.0125697324930258,1.0127673830722617,1.0129650722322985,1.0131627999806676,1.0133605663249008,1.0135583712725322,1.0137562148310968,1.0139540970081318,1.014152017811175,1.014349977247766,1.0145479753254463,1.0147460120517584,1.0149440874342464,1.0151422014804559,1.0153403541979338,1.0155385455942285,1.0157367756768905,1.015935044453471,1.0161333519315225,1.0163316981186001,1.0165300830222594,1.0167285066500578,1.016926969009554,1.0171254701083083,1.0173240099538827,1.0175225885538401,1.0177212059157459,1.0179198620471657,1.0181185569556674,1.01831729064882,1.0185160631341945,1.018714874419363,1.0189137245118987,1.019112613419377,1.0193115411493743,1.0195105077094688,1.01970951310724,1.0199085573502689,1.0201076404461378,1.0203067624024307,1.0205059232267333,1.0207051229266322,1.020904361509716,1.0211036389835746,1.021302955355799,1.0215023106339827,1.0217017048257195,1.0219011379386052,1.0221006099802374,1.0223001209582148,1.0224996708801375,1.0226992597536073,1.0228988875862275,1.0230985543856026,1.0232982601593392,1.0234980049150446,1.023697788660328,1.0238976114028004,1.0240974731500736,1.0242973739097612,1.0244973136894784,1.0246972924968418,1.0248973103394696,1.0250973672249812,1.0252974631609977,1.0254975981551417,1.025697772215037,1.0258979853483094,1.0260982375625858,1.0262985288654947,1.026498859264666,1.0266992287677315,1.0268996373823236,1.0271000851160772,1.0273005719766282,1.0275010979716137,1.027701663108673,1.0279022673954463,1.0281029108395758,1.0283035934487046,1.0285043152304776,1.0287050761925411,1.0289058763425434,1.0291067156881335,1.0293075942369625,1.0295085119966825,1.0297094689749475,1.0299104651794126,1.0301115006177353,1.030312575297573,1.0305136892265863,1.0307148424124362,1.0309160348627855,1.0311172665852986,1.0313185375876412,1.0315198478774807,1.0317211974624858,1.031922586350327,1.0321240145486759,1.0323254820652057,1.0325269889075916,1.0327285350835096,1.0329301206006374,1.0331317454666544,1.0333334096892417,1.033535113276081,1.0337368562348563,1.0339386385732532,1.03 ...

# %% [markdown]
# Since $P=EI$ it is ideal to

# %%
p/E == F/P
# Out:
# True

# %%
P_max, v_max, I_max = sympy.symbols(" P_max v_max I_max ")

# %% [markdown]
# Assuming there is both an upper bound on the total ejected mass ($M$) and a maximum power ($P_{max}$)used to eject particles, what is the ideal way to attain a momentum $p_{spaceship}$?

# %%
P_from_v = P.subs(y, 1/sympy.sqrt(1-(v/c)**2))
v_set_solns = sympy.solveset(sympy.Eq(P_from_v, P_max), v)
v_set_solns
# Out:
# Complement({-c*sqrt(P_max*(2*I*c**2*m_0 + P_max))/(I*c**2*m_0 + P_max), c*sqrt(P_max*(2*I*c**2*m_0 + P_max))/(I*c**2*m_0 + P_max)}, {-c, c})

# %%
v_str = str(v_set_solns)
str_bounds = v_str.rsplit("}")[-2][3:].rsplit(",")
v_bounds = [parse_expr(bound) for bound in str_bounds]
v_bounds
# Out:
# [-c, c]

# %%
v_str = str(v_set_solns.as_relational)
v_str_solns = v_str.rsplit("{")[1][:-3].rsplit(",")
v_solns = [parse_expr(soln) for soln in v_str_solns]
v_solns
# Out:
# [-c*sqrt(P_max*(P_max + 2*I*c**2*m_0))/(P_max + I*c**2*m_0),
#  c*sqrt(P_max*(P_max + 2*I*c**2*m_0))/(P_max + I*c**2*m_0)]

# %%
v_max = v_solns[1]
v_max
# Out:
# c*sqrt(P_max*(P_max + 2*I*c**2*m_0))/(P_max + I*c**2*m_0)

# %%
F_max = (I * m_0 * v_max * y).subs(y, 1/sympy.sqrt(1-(v_max/c)**2))
sympy.simplify(F_max)
# Out:
# I*c*m_0*sqrt(P_max*(P_max + 2*I*c**2*m_0))/(sqrt((-P_max*(P_max + 2*I*c**2*m_0) + (P_max + I*c**2*m_0)**2)/(P_max + I*c**2*m_0)**2)*(P_max + I*c**2*m_0))

# %% [markdown]
# Now to account for the mass of the propulsion system, including:
#
#
# *  Thruster
# *  Fuel or power source

# %%
a = sympy.symbols("a")
[x for x in sympy.solveset(sympy.Eq(a+1,b),a)][0]
# Out:
# b - 1
