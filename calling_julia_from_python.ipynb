# %%
!pip install julia
# Out:
# ...
#      -------------------------------------- 67.6/67.6 kB 521.8 kB/s eta 0:00:00
# ...

# %%
!pip install import-ipynb

# %%
import import_ipynb
import julia
#julia.install()

# %%
%load_ext julia.magic
# Out:
# Initializing Julia interpreter. This may take some time...

# %%
%%julia
using PlotlyJS
using BenchmarkTools
using Random

# %%
import read_exfor
# Out:
# importing Jupyter notebook from read_exfor.ipynb
# Traceback (most recent call last):
#
#   File c:\Users\engin\anaconda3\envs\Heroku_39_env\lib\site-packages\IPython\core\interactiveshell.py:3398 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [11] in <cell line: 1>
#     import read_exfor
#
#   File <frozen importlib._bootstrap>:1007 in _find_and_load
#
#   File <frozen importlib._bootstrap>:986 in _find_and_load_unlocked
#
#   File <frozen importlib._bootstrap>:664 in _load_unlocked
#
#   File <frozen importlib._bootstrap>:627 in _load_backward_compatible
#
#   File c:\Users\engin\anaconda3\envs\Heroku_39_env\lib\site-packages\import_ipynb.py:61 in load_module
#     exec(code, mod.__dict__)
#
#   File <string>:1
#     using Unitful #https://painterqubits.github.io/Unitful.jl/stable/
#           ^
# SyntaxError: invalid syntax

# %%
using BenchmarkTools
using Random
@btime [(rand() * x)^10 for x in 1.0:1000.0]
# Out:
#   43.900 μs (1 allocation: 7.94 KiB)
# 1000-element Vector{Float64}:
#     8.454732736205842e-6
#     0.05573497989402449
#  1552.1318100915607
#     3.8368414326263656e-9
#     3.996346667203697e-5
#     2.3886296608102262e7
#     4.059934085694962e7
#     5.643777760068282e6
#     1.1405968046310397e6
#     7.054578027046486e8
#     ⋮
#     8.503574142918943e24
#     7.698816021974009e28
#     1.50919965047783e24
#     1.029634380325541e17
#     8.517547943311298e6
#     2.5130524481821547e28
#     7.948212864441649e25
#     1.5504809274090286e12
#     6.226185640074927e24

# %%
%%julia
@btime [(rand() * x)^10 for x in 1.0:1000.0]
#using read_exfor.ipynb
# Out:
#   88.600 μs (1 allocation: 7.94 KiB)
# array([4.34418516e-05, 1.96036735e-10, 3.83262599e+00, 1.20764991e+01,
#        1.93343609e+04, 6.31744228e+04, 1.84566000e+08, 5.94598412e+07,
#        3.83915321e-07, 1.88978562e+08, 9.37094188e+09, 2.49802507e+06,
#        1.98376018e+08, 1.59582163e+06, 1.32584838e+09, 4.66943993e+11,
#        1.37996552e+05, 2.62684954e+09, 1.68488785e+04, 5.44255999e+08,
#        6.09840302e+10, 2.20285664e+11, 5.43431561e+11, 7.73902028e+08,
#        2.57664957e+11, 2.42241705e+08, 5.11857927e+09, 3.52985685e-02,
#        6.69460745e+13, 8.04079685e+12, 2.84983328e+08, 1.84224967e+11,
#        2.55325229e+14, 7.16621945e+11, 1.35881003e+14, 2.48665348e+10,
#        4.73654138e+11, 8.44079108e+11, 7.02694515e+15, 1.84782958e+10,
#        8.26276552e+14, 4.12514535e+10, 1.46361442e+11, 1.07083082e+16,
#        8.58822517e+15, 1.24926804e+06, 3.07659396e+16, 1.84060145e+12,
#        2.03122278e+10, 2.29345449e+15, 1.19826533e+15, 1.20071987e+17,
# ...

# %%
%%timeit 
[(x*random.random())**10 for x in range(1,1000)]
# Out:
# 336 µs ± 28.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
%run read_exfor.ipynb
# Out:
#   File ~\AppData\Local\Temp\ipykernel_3976\2347775733.py:1
#     using Unitful #https://painterqubits.github.io/Unitful.jl/stable/
#           ^
# SyntaxError: invalid syntax
# Traceback (most recent call last):
#
#   File c:\Users\engin\anaconda3\envs\Heroku_39_env\lib\site-packages\IPython\core\interactiveshell.py:3398 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [8] in <cell line: 1>
#     get_ipython().run_line_magic('run', 'read_exfor.ipynb')
#
#   File c:\Users\engin\anaconda3\envs\Heroku_39_env\lib\site-packages\IPython\core\interactiveshell.py:2305 in run_line_magic
#     result = fn(*args, **kwargs)
#
#   File c:\Users\engin\anaconda3\envs\Heroku_39_env\lib\site-packages\IPython\core\magics\execution.py:717 in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#
#   File c:\Users\engin\anaconda3\envs\Heroku_39_env\lib\site-packages\IPython\core\interactiveshell.py:2811 in safe_execfile_ipy
#     result.raise_error()
# ...
